# %%
import pandas as pd
import re

# %%
#arquivo = 'afastamentos'
arquivo = 'cadastro'

# %%
df = pd.read_csv(arquivo + '.csv.bz2', sep=';',
                 usecols=['Id_SERVIDOR_PORTAL', 'NOME'], index_col=0)

# %%
df.head(10)
# Out:
#                                               NOME
# Id_SERVIDOR_PORTAL
# 5116961                 AARAO CARLOS LUZ MACAMBIRA
# 201964                   AARAO DIAMANTINO OLIVEIRA
# 4405000                   AARAO FERREIRA LIMA NETO
# 4915841             AARAO PEREIRA DE ARAUJO JUNIOR
# 5105492                               AARAO SOARES
# 8114023                  AARAO TEIXEIRA DOS SANTOS
# 82440282                     AARON DA COSTA TELLES
# 2671                          AARON DE SOUSA ALVES
# 107618548                    AARON ENRICO YAMAFUKO
# 16237                          AARON INACIO FREIRE

# %%
def remover_preposicoes(str):
    return re.sub(" D[A|E|O]S? ", " ", str)

# %%
exemplos = [
    "BELCHIOR DA CUNHA NETO",
    "ABADIO ALVES DE LIMA FILHO",
    "ALBINO GOMES DOS SANTOS JUNIOR"
]

for ex in exemplos:
    print(ex, "=>", remover_preposicoes(ex))
# Out:
# BELCHIOR DA CUNHA NETO => BELCHIOR CUNHA NETO
# ABADIO ALVES DE LIMA FILHO => ABADIO ALVES LIMA FILHO
# ALBINO GOMES DOS SANTOS JUNIOR => ALBINO GOMES SANTOS JUNIOR

# %%
df['NOME2'] = df['NOME'].apply(remover_preposicoes)
df.head(30)
# Out:
#                                                    NOME  \
# Id_SERVIDOR_PORTAL
# 5116961                      AARAO CARLOS LUZ MACAMBIRA
# 201964                        AARAO DIAMANTINO OLIVEIRA
# 4405000                        AARAO FERREIRA LIMA NETO
# 4915841                  AARAO PEREIRA DE ARAUJO JUNIOR
# 5105492                                    AARAO SOARES
# 8114023                       AARAO TEIXEIRA DOS SANTOS
# 82440282                          AARON DA COSTA TELLES
# 2671                               AARON DE SOUSA ALVES
# 107618548                         AARON ENRICO YAMAFUKO
# 16237                               AARON INACIO FREIRE
# 7703888                        AARON RAFAEL ERMEL GOMES
# 196662779             AARON SCHWARTZ MARTINS DOS SANTOS
# 79840368                      AARONSON RAMATHAN FREITAS
# 5710805                   ABADIA ADENISIA ROCHA E SILVA
# 1713121                           ABADIA ALVES DA SILVA
# 76402944                      ABADIA APARECIDA FAUSTINO
# 5309978                            ABADIA CANDIDA LEMES
# 6403578                  ABADIA DA GLORIA ARAUJO SPEZIA
# 5113978                        ABADIA DE FATIMA RESENDE
# 6118494                    ABADIA DE FATIMA ROSA MACEDO
# 1617447                         ABADIA DE MELO COUTINHO
# 7505648                      ABADIA DOS REIS NASCIMENTO
# 94654656            ABADIA EVILIN FRAGOSO DO NASCIMENTO
# 5414482                        ABADIA GILDA BUSO MATOSO
# 406342                  ABADIA MARIA APARECIDA TEIXEIRA
# 5210013                       ABADIA RODRIGUES DA SILVA
# 54301412                        ABADIA RODRIGUES SOARES
# 7406431                           ABADIA SIQUEIRA GOMES
# 1711106                           ABADIA VIEIRA CALACIA
# 215473660                      ABADIA VIEIRA DOS SANTOS
#
#                                                NOME2
# Id_SERVIDOR_PORTAL
# 5116961                   AARAO CARLOS LUZ MACAMBIRA
# 201964                     AARAO DIAMANTINO OLIVEIRA
# 4405000                     AARAO FERREIRA LIMA NETO
# 4915841                  AARAO PEREIRA ARAUJO JUNIOR
# 5105492                                 AARAO SOARES
# 8114023                        AARAO TEIXEIRA SANTOS
# 82440282                          AARON COSTA TELLES
# 2671                               AARON SOUSA ALVES
# 107618548                      AARON ENRICO YAMAFUKO
# 16237                            AARON INACIO FREIRE
# 7703888                     AARON RAFAEL ERMEL GOMES
# 196662779              AARON SCHWARTZ MARTINS SANTOS
# 79840368                   AARONSON RAMATHAN FREITAS
# 5710805                ABADIA ADENISIA ROCHA E SILVA
# 1713121                           ABADIA ALVES SILVA
# 76402944                   ABADIA APARECIDA FAUSTINO
# 5309978                         ABADIA CANDIDA LEMES
# 6403578                  ABADIA GLORIA ARAUJO SPEZIA
# 5113978                        ABADIA FATIMA RESENDE
# 6118494                    ABADIA FATIMA ROSA MACEDO
# 1617447                         ABADIA MELO COUTINHO
# 7505648                       ABADIA REIS NASCIMENTO
# 94654656            ABADIA EVILIN FRAGOSO NASCIMENTO
# 5414482                     ABADIA GILDA BUSO MATOSO
# 406342               ABADIA MARIA APARECIDA TEIXEIRA
# 5210013                       ABADIA RODRIGUES SILVA
# 54301412                     ABADIA RODRIGUES SOARES
# 7406431                        ABADIA SIQUEIRA GOMES
# 1711106                        ABADIA VIEIRA CALACIA
# 215473660                       ABADIA VIEIRA SANTOS

# %%
def obter_primeiro_nome(str):
    return re.split("\s", str)[0]

# %%
for ex in exemplos:
    print(ex, "=>", obter_primeiro_nome(ex))
# Out:
# BELCHIOR DA CUNHA NETO => BELCHIOR
# ABADIO ALVES DE LIMA FILHO => ABADIO
# ALBINO GOMES DOS SANTOS JUNIOR => ALBINO

# %%
def obter_ultimo_nome(str):
    nomes = re.split("\s", str)
    ultimo = nomes[-1]
    if ultimo not in ["FILHO", "JUNIOR", "NETO", "SOBRINHO", "JR", "SEGUNDO", "TERCEIRO"]:
        return ultimo
    else:
        return nomes[-2]

# %%
for ex in exemplos:
    print(ex, "=>", obter_ultimo_nome(ex))
# Out:
# BELCHIOR DA CUNHA NETO => CUNHA
# ABADIO ALVES DE LIMA FILHO => LIMA
# ALBINO GOMES DOS SANTOS JUNIOR => SANTOS

# %%
df['PNOME'] = df['NOME2'].apply(obter_primeiro_nome)
df['UNOME'] = df['NOME2'].apply(obter_ultimo_nome)
df.head(30)
# Out:
#                                                    NOME  \
# Id_SERVIDOR_PORTAL
# 5116961                      AARAO CARLOS LUZ MACAMBIRA
# 201964                        AARAO DIAMANTINO OLIVEIRA
# 4405000                        AARAO FERREIRA LIMA NETO
# 4915841                  AARAO PEREIRA DE ARAUJO JUNIOR
# 5105492                                    AARAO SOARES
# 8114023                       AARAO TEIXEIRA DOS SANTOS
# 82440282                          AARON DA COSTA TELLES
# 2671                               AARON DE SOUSA ALVES
# 107618548                         AARON ENRICO YAMAFUKO
# 16237                               AARON INACIO FREIRE
# 7703888                        AARON RAFAEL ERMEL GOMES
# 196662779             AARON SCHWARTZ MARTINS DOS SANTOS
# 79840368                      AARONSON RAMATHAN FREITAS
# 5710805                   ABADIA ADENISIA ROCHA E SILVA
# 1713121                           ABADIA ALVES DA SILVA
# 76402944                      ABADIA APARECIDA FAUSTINO
# 5309978                            ABADIA CANDIDA LEMES
# 6403578                  ABADIA DA GLORIA ARAUJO SPEZIA
# 5113978                        ABADIA DE FATIMA RESENDE
# 6118494                    ABADIA DE FATIMA ROSA MACEDO
# 1617447                         ABADIA DE MELO COUTINHO
# 7505648                      ABADIA DOS REIS NASCIMENTO
# 94654656            ABADIA EVILIN FRAGOSO DO NASCIMENTO
# 5414482                        ABADIA GILDA BUSO MATOSO
# 406342                  ABADIA MARIA APARECIDA TEIXEIRA
# 5210013                       ABADIA RODRIGUES DA SILVA
# 54301412                        ABADIA RODRIGUES SOARES
# 7406431                           ABADIA SIQUEIRA GOMES
# 1711106                           ABADIA VIEIRA CALACIA
# 215473660                      ABADIA VIEIRA DOS SANTOS
#
#                                                NOME2     PNOME       UNOME
# Id_SERVIDOR_PORTAL
# 5116961                   AARAO CARLOS LUZ MACAMBIRA     AARAO   MACAMBIRA
# 201964                     AARAO DIAMANTINO OLIVEIRA     AARAO    OLIVEIRA
# 4405000                     AARAO FERREIRA LIMA NETO     AARAO        LIMA
# 4915841                  AARAO PEREIRA ARAUJO JUNIOR     AARAO      ARAUJO
# 5105492                                 AARAO SOARES     AARAO      SOARES
# 8114023                        AARAO TEIXEIRA SANTOS     AARAO      SANTOS
# 82440282                          AARON COSTA TELLES     AARON      TELLES
# 2671                               AARON SOUSA ALVES     AARON       ALVES
# 107618548                      AARON ENRICO YAMAFUKO     AARON    YAMAFUKO
# 16237                            AARON INACIO FREIRE     AARON      FREIRE
# 7703888                     AARON RAFAEL ERMEL GOMES     AARON       GOMES
# 196662779              AARON SCHWARTZ MARTINS SANTOS     AARON      SANTOS
# 79840368                   AARONSON RAMATHAN FREITAS  AARONSON     FREITAS
# 5710805                ABADIA ADENISIA ROCHA E SILVA    ABADIA       SILVA
# 1713121                           ABADIA ALVES SILVA    ABADIA       SILVA
# 76402944                   ABADIA APARECIDA FAUSTINO    ABADIA    FAUSTINO
# 5309978                         ABADIA CANDIDA LEMES    ABADIA       LEMES
# 6403578                  ABADIA GLORIA ARAUJO SPEZIA    ABADIA      SPEZIA
# 5113978                        ABADIA FATIMA RESENDE    ABADIA     RESENDE
# 6118494                    ABADIA FATIMA ROSA MACEDO    ABADIA      MACEDO
# 1617447                         ABADIA MELO COUTINHO    ABADIA    COUTINHO
# 7505648                       ABADIA REIS NASCIMENTO    ABADIA  NASCIMENTO
# 94654656            ABADIA EVILIN FRAGOSO NASCIMENTO    ABADIA  NASCIMENTO
# 5414482                     ABADIA GILDA BUSO MATOSO    ABADIA      MATOSO
# 406342               ABADIA MARIA APARECIDA TEIXEIRA    ABADIA    TEIXEIRA
# 5210013                       ABADIA RODRIGUES SILVA    ABADIA       SILVA
# 54301412                     ABADIA RODRIGUES SOARES    ABADIA      SOARES
# 7406431                        ABADIA SIQUEIRA GOMES    ABADIA       GOMES
# 1711106                        ABADIA VIEIRA CALACIA    ABADIA     CALACIA
# 215473660                       ABADIA VIEIRA SANTOS    ABADIA      SANTOS

# %% [markdown]
# ## Nomes

# %%
maiores_nomes = df[['PNOME', 'UNOME']].\
    groupby(['PNOME']).count().sort_values(['UNOME'], ascending=False)
maiores_nomes.rename(columns={'UNOME': 'QTDE'}, inplace=True)

# %%
qtd_total = maiores_nomes['QTDE'].sum()
qtd_total
# Out:
# 645476

# %%
maiores_nomes['PERC'] = maiores_nomes['QTDE'].apply(lambda x: x / qtd_total * 100.0)
maiores_nomes.head(30)
# Out:
#             QTDE      PERC
# PNOME
# MARIA      20389  3.158754
# JOSE       15925  2.467172
# ANA        11497  1.781166
# JOAO        7515  1.164257
# CARLOS      7370  1.141793
# PAULO       7218  1.118245
# ANTONIO     6982  1.081682
# LUIZ        6139  0.951081
# FRANCISCO   5795  0.897787
# MARCELO     4979  0.771369
# MARCOS      4542  0.703667
# ANDRE       4297  0.665710
# RODRIGO     3986  0.617529
# RAFAEL      3843  0.595375
# RICARDO     3761  0.582671
# FERNANDO    3677  0.569657
# PEDRO       3659  0.566868
# EDUARDO     3624  0.561446
# FERNANDA    3530  0.546883
# PATRICIA    3434  0.532010
# DANIEL      3430  0.531391
# ALEXANDRE   3392  0.525504
# JULIANA     3386  0.524574
# BRUNO       3279  0.507997
# MARCIA      3203  0.496223
# FABIO       3134  0.485533
# LEONARDO    3024  0.468491
# LUCIANA     2987  0.462759
# SERGIO      2950  0.457027
# LUIS        2848  0.441225

# %% [markdown]
# ## Sobrenomes

# %%
maiores_sobrenomes = df[['PNOME', 'UNOME']].\
    groupby(['UNOME']).count().sort_values(['PNOME'], ascending=False)
maiores_sobrenomes.rename(columns={'PNOME': 'QTDE'}, inplace=True)

# %%
maiores_sobrenomes['PERC'] = maiores_sobrenomes['QTDE'].apply(lambda x: x / qtd_total * 100.0)
maiores_sobrenomes.head(30)
# Out:
#              QTDE      PERC
# UNOME
# SILVA       48617  7.531961
# SANTOS      26656  4.129666
# OLIVEIRA    21617  3.349001
# SOUZA       15604  2.417441
# LIMA        11941  1.849953
# COSTA       11019  1.707112
# PEREIRA      8645  1.339322
# FERREIRA     8365  1.295943
# ARAUJO       7969  1.234593
# CARVALHO     7319  1.133892
# ALMEIDA      6612  1.024360
# RODRIGUES    6548  1.014445
# SOUSA        6206  0.961461
# NASCIMENTO   5859  0.907702
# RIBEIRO      5356  0.829775
# GOMES        5317  0.823733
# ALVES        5163  0.799875
# ROCHA        4666  0.722877
# MARTINS      4549  0.704751
# BARBOSA      4449  0.689259
# MELO         4204  0.651302
# SOARES       4045  0.626669
# ANDRADE      4013  0.621712
# LOPES        3891  0.602811
# FREITAS      3740  0.579417
# VIEIRA       3554  0.550601
# GONCALVES    3523  0.545799
# FERNANDES    3431  0.531546
# DIAS         3262  0.505363
# MACHADO      3116  0.482745

# %% [markdown]
# ### Geração dos arquivos resultantes

# %%
maiores_nomes.to_csv(arquivo + '-nomes.csv', float_format='%.4f')
maiores_sobrenomes.to_csv(arquivo + '-sobrenomes.csv', float_format='%.4f')
